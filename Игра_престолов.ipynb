# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniela24230/Contr2/blob/main/%D0%98%D0%B3%D1%80%D0%B0_%D0%BF%D1%80%D0%B5%D1%81%D1%82%D0%BE%D0%BB%D0%BE%D0%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
battles = pd.read_csv('battles.csv')
battles
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battles.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battles.shape
# Out:
# (38, 25)

# %%
battles.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
for i in battles.columns:
    print(i)
# Out:
# name
# year
# battle_number
# attacker_king
# defender_king
# attacker_1
# attacker_2
# attacker_3
# attacker_4
# defender_1
# defender_2
# defender_3
# defender_4
# attacker_outcome
# battle_type
# major_death
# major_capture
# attacker_size
# defender_size
# attacker_commander
# defender_commander
# summer
# location
# region
# note

# %%
battles.describe()
# Out:
#              year  battle_number  defender_3  defender_4  major_death  \
# count   38.000000      38.000000         0.0         0.0    37.000000
# mean   299.105263      19.500000         NaN         NaN     0.351351
# std      0.689280      11.113055         NaN         NaN     0.483978
# min    298.000000       1.000000         NaN         NaN     0.000000
# 25%    299.000000      10.250000         NaN         NaN     0.000000
# 50%    299.000000      19.500000         NaN         NaN     0.000000
# 75%    300.000000      28.750000         NaN         NaN     1.000000
# max    300.000000      38.000000         NaN         NaN     1.000000
#
#        major_capture  attacker_size  defender_size     summer
# count      37.000000      24.000000      19.000000  37.000000
# mean        0.297297    9942.541667    6428.157895   0.702703
# std         0.463373   20283.092065    6225.182106   0.463373
# min         0.000000      20.000000     100.000000   0.000000
# ...

# %%
battles.dtypes
# Out:
# name                   object
# year                    int64
# battle_number           int64
# attacker_king          object
# defender_king          object
# attacker_1             object
# attacker_2             object
# attacker_3             object
# attacker_4             object
# defender_1             object
# defender_2             object
# defender_3            float64
# defender_4            float64
# attacker_outcome       object
# battle_type            object
# major_death           float64
# major_capture         float64
# attacker_size         float64
# defender_size         float64
# attacker_commander     object
# defender_commander     object
# summer                float64
# location               object
# region                 object
# note                   object
# dtype: object

# %%
battles.isnull()
# Out:
#      name   year  battle_number  attacker_king  defender_king  attacker_1  \
# 0   False  False          False          False          False       False
# 1   False  False          False          False          False       False
# 2   False  False          False          False          False       False
# 3   False  False          False          False          False       False
# 4   False  False          False          False          False       False
# 5   False  False          False          False          False       False
# 6   False  False          False          False          False       False
# 7   False  False          False          False          False       False
# 8   False  False          False          False          False       False
# 9   False  False          False          False          False       False
# 10  False  False          False          False          False       False
# 11  False  False          False          False          False       False
# ...

# %%
battles.isnull().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
battles=battles[['name','attacker_king','defender_king','attacker_outcome','battle_type','major_death','major_capture','attacker_size','defender_size','attacker_commander','defender_commander','location','region']]
battles
# Out:
#                                                  name  \
# 0                          Battle of the Golden Tooth
# 1                         Battle at the Mummer's Ford
# 2                                  Battle of Riverrun
# 3                            Battle of the Green Fork
# 4                       Battle of the Whispering Wood
# 5                                 Battle of the Camps
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 10                         Battle of Torrhen's Square
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 13                                 Sack of Winterfell
# 14                                  Battle of Oxcross
# 15                               Siege of Storm's End
# ...

# %%
battles.shape
# Out:
# (38, 13)

# %%
battles.dtypes
# Out:
# name                   object
# attacker_king          object
# defender_king          object
# attacker_outcome       object
# battle_type            object
# major_death           float64
# major_capture         float64
# attacker_size         float64
# defender_size         float64
# attacker_commander     object
# defender_commander     object
# location               object
# region                 object
# dtype: object

# %%
pd.options.mode.chained_assignment=None

# %%
battles['major_death'] = battles['major_death'].astype('bool')

# %%
battles.dtypes
# Out:
# name                   object
# attacker_king          object
# defender_king          object
# attacker_outcome       object
# battle_type            object
# major_death              bool
# major_capture         float64
# attacker_size         float64
# defender_size         float64
# attacker_commander     object
# defender_commander     object
# location               object
# region                 object
# dtype: object

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          2
# defender_king          3
# attacker_outcome       1
# battle_type            1
# major_death            0
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles[battles['attacker_king'].isnull()]
# Out:
#                             name attacker_king defender_king attacker_outcome  \
# 22  Battle of the Burning Septry           NaN           NaN              win
# 29              Sack of Saltpans           NaN           NaN              win
#
#        battle_type  major_death  major_capture  attacker_size  defender_size  \
# 22  pitched battle        False            0.0            NaN            NaN
# 29          razing        False            0.0            NaN            NaN
#
#    attacker_commander defender_commander  location          region
# 22                NaN                NaN       NaN  The Riverlands
# 29              Rorge                NaN  Saltpans  The Riverlands

# %%
battles.fillna({'attacker_king':'No King'},inplace=True)

# %%
battles[battles['defender_king'].isnull()]
# Out:
#                             name             attacker_king defender_king  \
# 22  Battle of the Burning Septry                   No King           NaN
# 24         Retaking of Harrenhal  Joffrey/Tommen Baratheon           NaN
# 29              Sack of Saltpans                   No King           NaN
#
#    attacker_outcome     battle_type  major_death  major_capture  \
# 22              win  pitched battle        False            0.0
# 24              win  pitched battle         True            0.0
# 29              win          razing        False            0.0
#
#     attacker_size  defender_size attacker_commander defender_commander  \
# 22            NaN            NaN                NaN                NaN
# 24            NaN            NaN     Gregor Clegane         Vargo Hoat
# 29            NaN            NaN              Rorge                NaN
#
#      location          region
# 22        NaN  The Riverlands
# 24  Harrenhal  The Riverlands
# 29   Saltpans  The Riverlands

# %%
battles.fillna({'defender_king':'No King'},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          0
# defender_king          0
# attacker_outcome       1
# battle_type            1
# major_death            0
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles[battles['attacker_outcome'].isnull()]
# Out:
#                    name      attacker_king             defender_king  \
# 37  Siege of Winterfell  Stannis Baratheon  Joffrey/Tommen Baratheon
#
#    attacker_outcome battle_type  major_death  major_capture  attacker_size  \
# 37              NaN         NaN         True            NaN         5000.0
#
#     defender_size attacker_commander defender_commander    location     region
# 37         8000.0  Stannis Baratheon       Roose Bolton  Winterfell  The North

# %%
battles.fillna({'attacker_outcome':'loss'},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          0
# defender_king          0
# attacker_outcome       0
# battle_type            1
# major_death            0
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles[battles['battle_type'].isnull()]
# Out:
#                    name      attacker_king             defender_king  \
# 37  Siege of Winterfell  Stannis Baratheon  Joffrey/Tommen Baratheon
#
#    attacker_outcome battle_type  major_death  major_capture  attacker_size  \
# 37             loss         NaN         True            NaN         5000.0
#
#     defender_size attacker_commander defender_commander    location     region
# 37         8000.0  Stannis Baratheon       Roose Bolton  Winterfell  The North

# %%
battles['battle_type'].value_counts()
# Out:
# battle_type
# pitched battle    14
# siege             11
# ambush            10
# razing             2
# Name: count, dtype: int64

# %%
battles.fillna({'battle_type':'siege'},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          0
# defender_king          0
# attacker_outcome       0
# battle_type            0
# major_death            0
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles['attacker_size'].value_counts()
# Out:
# attacker_size
# 6000.0      3
# 15000.0     2
# 3000.0      2
# 5000.0      2
# 1000.0      1
# 264.0       1
# 244.0       1
# 20.0        1
# 618.0       1
# 18000.0     1
# 20000.0     1
# 100.0       1
# 21000.0     1
# 1875.0      1
# 3500.0      1
# 100000.0    1
# 4500.0      1
# 2000.0      1
# 1500.0      1
# Name: count, dtype: int64

# %%
battles[battles['attacker_size'].isnull()]
# Out:
#                                                  name  \
# 1                         Battle at the Mummer's Ford
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 12                           Sack of Torrhen's Square
# 20                                     Siege of Darry
# 22                       Battle of the Burning Septry
# 23                            Battle of the Ruby Ford
# 24                              Retaking of Harrenhal
# 26                                   Siege of Seagard
# 28                                Fall of Moat Cailin
# 29                                   Sack of Saltpans
# 31                       Battle of the Shield Islands
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...
# 33                        Second Seige of Storm's End
#
#                attacker_king             defender_king attacker_outcome  \
# 1   Joffrey/Tommen Baratheon                Robb Stark              win
# ...

# %%
attacker_size_sum=battles.attacker_size.sum()
attacker_size_sum
# Out:
# 238621.0

# %%
average=attacker_size_sum/38
average
# Out:
# 6279.5

# %%
battles.fillna({'attacker_size':6280},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          0
# defender_king          0
# attacker_outcome       0
# battle_type            0
# major_death            0
# major_capture          1
# attacker_size          0
# defender_size         19
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles['defender_size'].value_counts()
# Out:
# defender_size
# 10000.0    3
# 20000.0    2
# 6000.0     2
# 200.0      2
# 4000.0     1
# 120.0      1
# 12625.0    1
# 900.0      1
# 2000.0     1
# 100.0      1
# 7250.0     1
# 3500.0     1
# 1240.0     1
# 8000.0     1
# Name: count, dtype: int64

# %%
battles[battles['defender_size'].isnull()]
# Out:
#                                                  name  \
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 18                                 Battle of the Crag
# 20                                     Siege of Darry
# 21                               Battle of Duskendale
# 22                       Battle of the Burning Septry
# 24                              Retaking of Harrenhal
# 26                                   Siege of Seagard
# 28                                Fall of Moat Cailin
# 29                                   Sack of Saltpans
# 31                       Battle of the Shield Islands
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...
# ...

# %%
defender_size_sum=battles.defender_size.sum()
defender_size_sum
# Out:
# 122135.0

# %%
average=defender_size_sum/38
average
# Out:
# 3214.0789473684213

# %%
battles.fillna({'defender_size':3214},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                   0
# attacker_king          0
# defender_king          0
# attacker_outcome       0
# battle_type            0
# major_death            0
# major_capture          1
# attacker_size          0
# defender_size          0
# attacker_commander     1
# defender_commander    10
# location               1
# region                 0
# dtype: int64

# %%
battles[battles['attacker_commander'].isnull()]
# Out:
#                             name attacker_king defender_king attacker_outcome  \
# 22  Battle of the Burning Septry       No King       No King              win
#
#        battle_type  major_death  major_capture  attacker_size  defender_size  \
# 22  pitched battle        False            0.0         6280.0         3214.0
#
#    attacker_commander defender_commander location          region
# 22                NaN                NaN      NaN  The Riverlands

# %%
battles[battles['defender_commander'].isnull()]
# Out:
#                                                  name  \
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 12                           Sack of Torrhen's Square
# 20                                     Siege of Darry
# 22                       Battle of the Burning Septry
# 28                                Fall of Moat Cailin
# 29                                   Sack of Saltpans
# 31                       Battle of the Shield Islands
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...
#
#                attacker_king             defender_king attacker_outcome  \
# 7        Balon/Euron Greyjoy                Robb Stark              win
# 8        Balon/Euron Greyjoy                Robb Stark              win
# 9        Balon/Euron Greyjoy                Robb Stark              win
# 12       Balon/Euron Greyjoy       Balon/Euron Greyjoy              win
# ...

# %%
battles.fillna({'attacker_commander':'No Commander','defender_commander':'No Commander'},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                  0
# attacker_king         0
# defender_king         0
# attacker_outcome      0
# battle_type           0
# major_death           0
# major_capture         1
# attacker_size         0
# defender_size         0
# attacker_commander    0
# defender_commander    0
# location              1
# region                0
# dtype: int64

# %%
battles[battles['location'].isnull()]
# Out:
#                             name attacker_king defender_king attacker_outcome  \
# 22  Battle of the Burning Septry       No King       No King              win
#
#        battle_type  major_death  major_capture  attacker_size  defender_size  \
# 22  pitched battle        False            0.0         6280.0         3214.0
#
#    attacker_commander defender_commander location          region
# 22       No Commander       No Commander      NaN  The Riverlands

# %%
a=battles[battles['region']=='The Riverlands']
a
# Out:
#                              name             attacker_king  \
# 1     Battle at the Mummer's Ford  Joffrey/Tommen Baratheon
# 2              Battle of Riverrun  Joffrey/Tommen Baratheon
# 3        Battle of the Green Fork                Robb Stark
# 4   Battle of the Whispering Wood                Robb Stark
# 5             Battle of the Camps                Robb Stark
# 6                   Sack of Darry  Joffrey/Tommen Baratheon
# 16            Battle of the Fords  Joffrey/Tommen Baratheon
# 17              Sack of Harrenhal                Robb Stark
# 20                 Siege of Darry                Robb Stark
# 22   Battle of the Burning Septry                   No King
# 23        Battle of the Ruby Ford  Joffrey/Tommen Baratheon
# 24          Retaking of Harrenhal  Joffrey/Tommen Baratheon
# 25                The Red Wedding  Joffrey/Tommen Baratheon
# 26               Siege of Seagard                Robb Stark
# 29               Sack of Saltpans                   No King
# ...

# %%
a['location'].value_counts()
# Out:
# location
# Riverrun           3
# Darry              2
# Harrenhal          2
# Mummer's Ford      1
# Green Fork         1
# Whispering Wood    1
# Red Fork           1
# Ruby Ford          1
# The Twins          1
# Seagard            1
# Saltpans           1
# Raventree          1
# Name: count, dtype: int64

# %%
battles.fillna({'location':'Riverrun'},inplace=True)

# %%
battles.isnull().sum()
# Out:
# name                  0
# attacker_king         0
# defender_king         0
# attacker_outcome      0
# battle_type           0
# major_death           0
# major_capture         1
# attacker_size         0
# defender_size         0
# attacker_commander    0
# defender_commander    0
# location              0
# region                0
# dtype: int64

# %%
battles.dtypes
# Out:
# name                   object
# attacker_king          object
# defender_king          object
# attacker_outcome       object
# battle_type            object
# major_death              bool
# major_capture         float64
# attacker_size         float64
# defender_size         float64
# attacker_commander     object
# defender_commander     object
# location               object
# region                 object
# dtype: object

# %%
battles['attacker_size'] = battles['attacker_size'].apply(int)

# %%
battles['defender_size'] = battles['defender_size'].apply(int)

# %%
battles.dtypes
# Out:
# name                   object
# attacker_king          object
# defender_king          object
# attacker_outcome       object
# battle_type            object
# major_death              bool
# major_capture         float64
# attacker_size           int64
# defender_size           int64
# attacker_commander     object
# defender_commander     object
# location               object
# region                 object
# dtype: object

# %%
battles
# Out:
#                                                  name  \
# 0                          Battle of the Golden Tooth
# 1                         Battle at the Mummer's Ford
# 2                                  Battle of Riverrun
# 3                            Battle of the Green Fork
# 4                       Battle of the Whispering Wood
# 5                                 Battle of the Camps
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 10                         Battle of Torrhen's Square
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 13                                 Sack of Winterfell
# 14                                  Battle of Oxcross
# 15                               Siege of Storm's End
# ...

# %%
battles.dtypes
# Out:
# name                   object
# attacker_king          object
# defender_king          object
# attacker_outcome       object
# battle_type            object
# major_death              bool
# major_capture         float64
# attacker_size           int64
# defender_size           int64
# attacker_commander     object
# defender_commander     object
# location               object
# region                 object
# dtype: object

# %%
battles["attacker_king"].value_counts()
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# No King                      2
# Name: count, dtype: int64

# %%
battles["attacker_king"].value_counts()[0:5]
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# No King                      2
# Name: count, dtype: int64

# %%
battles["attacker_king"].value_counts().index[0:5]
# Out:
# Index(['Joffrey/Tommen Baratheon', 'Robb Stark', 'Balon/Euron Greyjoy',
#        'Stannis Baratheon', 'No King'],
#       dtype='object', name='attacker_king')

# %%
plt.figure(figsize=(11,5))
sns.countplot(x='attacker_king',order=battles['attacker_king'].value_counts().index[0:5],data=battles, palette = my_palette)
plt.title('Наиболее враждебные короли',fontsize=15)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-167-7b2df364dabd>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='attacker_king',order=battles['attacker_king'].value_counts().index[0:5],data=battles, palette = my_palette)
# <ipython-input-167-7b2df364dabd>:2: UserWarning: The palette list has more values (7) than needed (5), which may not be intended.
#   sns.countplot(x='attacker_king',order=battles['attacker_king'].value_counts().index[0:5],data=battles, palette = my_palette)

# %%
battles["location"].value_counts()
# Out:
# location
# Riverrun                                4
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
battles["location"].value_counts()[0:5]
# Out:
# location
# Riverrun       4
# Winterfell     3
# Storm's End    2
# Harrenhal      2
# Darry          2
# Name: count, dtype: int64

# %%
battles["location"].value_counts().index[0:5]
# Out:
# Index(['Riverrun', 'Winterfell', 'Storm's End', 'Harrenhal', 'Darry'], dtype='object', name='location')

# %%
plt.figure(figsize=(11,5))
sns.countplot(x='location',order=battles["location"].value_counts().index[0:5],data=battles,palette = my_palette)
plt.title('Места сражений',fontsize=15)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-166-da4d466a00d7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='location',order=battles["location"].value_counts().index[0:5],data=battles,palette = my_palette)
# <ipython-input-166-da4d466a00d7>:2: UserWarning: The palette list has more values (7) than needed (5), which may not be intended.
#   sns.countplot(x='location',order=battles["location"].value_counts().index[0:5],data=battles,palette = my_palette)

# %%
att_with_most=battles[['attacker_king','attacker_size']]
att_with_most
# Out:
#                attacker_king  attacker_size
# 0   Joffrey/Tommen Baratheon          15000
# 1   Joffrey/Tommen Baratheon           6280
# 2   Joffrey/Tommen Baratheon          15000
# 3                 Robb Stark          18000
# 4                 Robb Stark           1875
# 5                 Robb Stark           6000
# 6   Joffrey/Tommen Baratheon           6280
# 7        Balon/Euron Greyjoy           6280
# 8        Balon/Euron Greyjoy           1000
# 9        Balon/Euron Greyjoy            264
# 10                Robb Stark            244
# 11       Balon/Euron Greyjoy             20
# 12       Balon/Euron Greyjoy           6280
# 13  Joffrey/Tommen Baratheon            618
# 14                Robb Stark           6000
# 15         Stannis Baratheon           5000
# 16  Joffrey/Tommen Baratheon          20000
# 17                Robb Stark            100
# 18                Robb Stark           6000
# 19         Stannis Baratheon          21000
# ...

# %%
a=att_with_most.sort_values(by='attacker_size',ascending=False)
a
# Out:
#                attacker_king  attacker_size
# 27         Stannis Baratheon         100000
# 19         Stannis Baratheon          21000
# 16  Joffrey/Tommen Baratheon          20000
# 3                 Robb Stark          18000
# 0   Joffrey/Tommen Baratheon          15000
# 2   Joffrey/Tommen Baratheon          15000
# 22                   No King           6280
# 20                Robb Stark           6280
# 7        Balon/Euron Greyjoy           6280
# 33  Joffrey/Tommen Baratheon           6280
# 32       Balon/Euron Greyjoy           6280
# 31       Balon/Euron Greyjoy           6280
# 29                   No King           6280
# 12       Balon/Euron Greyjoy           6280
# 28  Joffrey/Tommen Baratheon           6280
# 23  Joffrey/Tommen Baratheon           6280
# 26                Robb Stark           6280
# 24  Joffrey/Tommen Baratheon           6280
# 6   Joffrey/Tommen Baratheon           6280
# 1   Joffrey/Tommen Baratheon           6280
# ...

# %%
a=a.head()
a
# Out:
#                attacker_king  attacker_size
# 27         Stannis Baratheon         100000
# 19         Stannis Baratheon          21000
# 16  Joffrey/Tommen Baratheon          20000
# 3                 Robb Stark          18000
# 0   Joffrey/Tommen Baratheon          15000

# %%
x=list(a['attacker_king'])
x
# Out:
# ['Stannis Baratheon',
#  'Stannis Baratheon',
#  'Joffrey/Tommen Baratheon',
#  'Robb Stark',
#  'Joffrey/Tommen Baratheon']

# %%
y=list(a['attacker_size'])
y
# Out:
# [100000, 21000, 20000, 18000, 15000]

# %%
plt.figure(figsize=(10,5))
plt.bar(x,y, color=my_palette)
plt.grid(True)
plt.title("Нападающая армия",fontsize=15)
plt.xlabel('Атакующий король',fontsize=10)
plt.ylabel('Численность армии',fontsize=10)
plt.show()

# %%
def_with_most=battles[['defender_king','defender_size']]
def_with_most
# Out:
#                defender_king  defender_size
# 0                 Robb Stark           4000
# 1                 Robb Stark            120
# 2                 Robb Stark          10000
# 3   Joffrey/Tommen Baratheon          20000
# 4   Joffrey/Tommen Baratheon           6000
# 5   Joffrey/Tommen Baratheon          12625
# 6                 Robb Stark           3214
# 7                 Robb Stark           3214
# 8                 Robb Stark           3214
# 9                 Robb Stark           3214
# 10       Balon/Euron Greyjoy            900
# 11                Robb Stark           3214
# 12       Balon/Euron Greyjoy           3214
# 13                Robb Stark           2000
# 14  Joffrey/Tommen Baratheon          10000
# 15           Renly Baratheon          20000
# 16                Robb Stark          10000
# 17  Joffrey/Tommen Baratheon            100
# 18  Joffrey/Tommen Baratheon           3214
# 19  Joffrey/Tommen Baratheon           7250
# ...

# %%
a=def_with_most.sort_values(by='defender_size',ascending=False)
a
# Out:
#                defender_king  defender_size
# 3   Joffrey/Tommen Baratheon          20000
# 15           Renly Baratheon          20000
# 5   Joffrey/Tommen Baratheon          12625
# 14  Joffrey/Tommen Baratheon          10000
# 2                 Robb Stark          10000
# 16                Robb Stark          10000
# 37  Joffrey/Tommen Baratheon           8000
# 19  Joffrey/Tommen Baratheon           7250
# 23                Robb Stark           6000
# 4   Joffrey/Tommen Baratheon           6000
# 0                 Robb Stark           4000
# 25                Robb Stark           3500
# 11                Robb Stark           3214
# 9                 Robb Stark           3214
# 36                Robb Stark           3214
# 35                Robb Stark           3214
# 34         Stannis Baratheon           3214
# 32  Joffrey/Tommen Baratheon           3214
# 31  Joffrey/Tommen Baratheon           3214
# 29                   No King           3214
# ...

# %%
a=a.head()
a
# Out:
#                defender_king  defender_size
# 3   Joffrey/Tommen Baratheon          20000
# 15           Renly Baratheon          20000
# 5   Joffrey/Tommen Baratheon          12625
# 14  Joffrey/Tommen Baratheon          10000
# 2                 Robb Stark          10000

# %%
x=list(a['defender_king'])
x
# Out:
# ['Joffrey/Tommen Baratheon',
#  'Renly Baratheon',
#  'Joffrey/Tommen Baratheon',
#  'Joffrey/Tommen Baratheon',
#  'Robb Stark']

# %%
y=list(a['defender_size'])
y
# Out:
# [20000, 20000, 12625, 10000, 10000]

# %%
plt.figure(figsize=(10,5))
plt.bar(x,y,color=my_palette)
plt.grid(True)
plt.title("Армия защитников",fontsize=15)
plt.xlabel('Король-защитник',fontsize=10)
plt.ylabel('Численность армии',fontsize=10)
plt.show()

# %%
x=battles["attacker_king"]
x
# Out:
# 0     Joffrey/Tommen Baratheon
# 1     Joffrey/Tommen Baratheon
# 2     Joffrey/Tommen Baratheon
# 3                   Robb Stark
# 4                   Robb Stark
# 5                   Robb Stark
# 6     Joffrey/Tommen Baratheon
# 7          Balon/Euron Greyjoy
# 8          Balon/Euron Greyjoy
# 9          Balon/Euron Greyjoy
# 10                  Robb Stark
# 11         Balon/Euron Greyjoy
# 12         Balon/Euron Greyjoy
# 13    Joffrey/Tommen Baratheon
# 14                  Robb Stark
# 15           Stannis Baratheon
# 16    Joffrey/Tommen Baratheon
# 17                  Robb Stark
# 18                  Robb Stark
# 19           Stannis Baratheon
# 20                  Robb Stark
# 21                  Robb Stark
# 22                     No King
# 23    Joffrey/Tommen Baratheon
# 24    Joffrey/Tommen Baratheon
# 25    Joffrey/Tommen Baratheon
# 26                  Robb Stark
# 27           Stannis Baratheon
# 28    Joffrey/Tommen Baratheon
# 29                     No King
# ...

# %%
y=battles["battle_type"]
y
# Out:
# 0     pitched battle
# 1             ambush
# 2     pitched battle
# 3     pitched battle
# 4             ambush
# 5             ambush
# 6     pitched battle
# 7     pitched battle
# 8              siege
# 9             ambush
# 10    pitched battle
# 11            ambush
# 12             siege
# 13            ambush
# 14            ambush
# 15             siege
# 16    pitched battle
# 17            ambush
# 18            ambush
# 19    pitched battle
# 20             siege
# 21    pitched battle
# 22    pitched battle
# 23    pitched battle
# 24    pitched battle
# 25            ambush
# 26             siege
# 27             siege
# 28             siege
# 29            razing
# 30    pitched battle
# 31    pitched battle
# 32            razing
# 33             siege
# 34             siege
# 35             siege
# 36             siege
# 37             siege
# Name: battle_type, dtype: object

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=battles["attacker_king"],hue=y, data=battles, palette=my_palette)
plt.title('Атакующие короли и типы сражений',fontsize=15)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-143-f49f747895f0>:2: UserWarning: The palette list has more values (7) than needed (4), which may not be intended.
#   sns.countplot(x=battles["attacker_king"],hue=y, data=battles, palette=my_palette)

# %%
a=battles[battles['attacker_outcome']=='win']
a
# Out:
#                                                  name  \
# 0                          Battle of the Golden Tooth
# 1                         Battle at the Mummer's Ford
# 2                                  Battle of Riverrun
# 4                       Battle of the Whispering Wood
# 5                                 Battle of the Camps
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 10                         Battle of Torrhen's Square
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 13                                 Sack of Winterfell
# 14                                  Battle of Oxcross
# 15                               Siege of Storm's End
# 17                                  Sack of Harrenhal
# ...

# %%
a=a[['attacker_king','attacker_outcome']]
a
# Out:
#                attacker_king attacker_outcome
# 0   Joffrey/Tommen Baratheon              win
# 1   Joffrey/Tommen Baratheon              win
# 2   Joffrey/Tommen Baratheon              win
# 4                 Robb Stark              win
# 5                 Robb Stark              win
# 6   Joffrey/Tommen Baratheon              win
# 7        Balon/Euron Greyjoy              win
# 8        Balon/Euron Greyjoy              win
# 9        Balon/Euron Greyjoy              win
# 10                Robb Stark              win
# 11       Balon/Euron Greyjoy              win
# 12       Balon/Euron Greyjoy              win
# 13  Joffrey/Tommen Baratheon              win
# 14                Robb Stark              win
# 15         Stannis Baratheon              win
# 17                Robb Stark              win
# 18                Robb Stark              win
# 20                Robb Stark              win
# 22                   No King              win
# ...

# %%
a=a['attacker_king'].value_counts()
a
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    13
# Robb Stark                   8
# Balon/Euron Greyjoy          7
# Stannis Baratheon            2
# No King                      2
# Name: count, dtype: int64

# %%
x=list(a.keys())
x
# Out:
# ['Joffrey/Tommen Baratheon',
#  'Robb Stark',
#  'Balon/Euron Greyjoy',
#  'Stannis Baratheon',
#  'No King']

# %%
y=list(a)
y
# Out:
# [13, 8, 7, 2, 2]

# %%
plt.figure(figsize=(10,5))
plt.bar(x,y,color=my_palette)
plt.grid(True)
plt.title("Битвы выиграные атакующим королём",fontsize=15)
plt.xlabel('Атакующий король',fontsize=13)
plt.ylabel('Сражение',fontsize=13)
plt.show()

# %%
battles['defender_king'].value_counts()
# Out:
# defender_king
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# No King                      3
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: count, dtype: int64

# %%
x=list(battles['defender_king'].value_counts().keys())
x
# Out:
# ['Robb Stark',
#  'Joffrey/Tommen Baratheon',
#  'Balon/Euron Greyjoy',
#  'No King',
#  'Stannis Baratheon',
#  'Renly Baratheon',
#  'Mance Rayder']

# %%
y=list(battles['defender_king'].value_counts())
y
# Out:
# [14, 13, 4, 3, 2, 1, 1]

# %%
plt.figure(figsize=(20,7))
plt.bar(x,y,color=my_palette)
plt.grid(True)
plt.title("На кого больше всего нападали?",fontsize=16)
plt.xlabel('Короли-защитники',fontsize=13)
plt.ylabel('Сражения',fontsize=13)
plt.show()

# %%
a=battles[battles['attacker_outcome']=='loss']
a
# Out:
#                         name             attacker_king  \
# 3   Battle of the Green Fork                Robb Stark
# 16       Battle of the Fords  Joffrey/Tommen Baratheon
# 19  Battle of the Blackwater         Stannis Baratheon
# 21      Battle of Duskendale                Robb Stark
# 27    Battle of Castle Black         Stannis Baratheon
# 37       Siege of Winterfell         Stannis Baratheon
#
#                defender_king attacker_outcome     battle_type  major_death  \
# 3   Joffrey/Tommen Baratheon             loss  pitched battle         True
# 16                Robb Stark             loss  pitched battle        False
# 19  Joffrey/Tommen Baratheon             loss  pitched battle         True
# 21  Joffrey/Tommen Baratheon             loss  pitched battle         True
# 27              Mance Rayder             loss           siege         True
# 37  Joffrey/Tommen Baratheon             loss           siege         True
#
# ...

# %%
a=a['defender_king'].value_counts()
a
# Out:
# defender_king
# Joffrey/Tommen Baratheon    4
# Robb Stark                  1
# Mance Rayder                1
# Name: count, dtype: int64

# %%
x=list(a.keys())
x
# Out:
# ['Joffrey/Tommen Baratheon', 'Robb Stark', 'Mance Rayder']

# %%
y=list(a)
y
# Out:
# [4, 1, 1]

# %%
plt.bar(x,y,color= my_palette)
plt.title("Короли преуспевшие в защите",fontsize=15)
plt.xlabel("Короли защитники",fontsize=10)
plt.ylabel("Сражения",fontsize=10)
plt.grid(True)
plt.show()

plt.figure(figsize=(7,7))
myexplode = [0.05, 0.05, 0.05]
plt.pie(y,labels=x,autopct='%0.1f%%',explode = myexplode,shadow = True, colors=my_palette)
plt.show()
